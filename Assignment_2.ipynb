# %% [markdown]
# <b>Question Bank : https://drive.google.com/file/d/1N4HfjYjQ4ZJJLfOAKqqPVlaM56QXdetj/view

# %% [markdown]
# <b>Q.1 What is the concept of human learning? Please give two examples.

# %% [markdown]
# Ans : Learning is the process of acquiring new understanding, knowledge, behaviors, skills, values, attitudes, and preferences. Human learning starts at birth (it might even start before) and continues until death as a consequence of ongoing interactions between people and their environment. Examples are at our childhood we see others and learn to stand and walk

# %% [markdown]
# <b>Q.2 What different forms of human learning are there? Are there any machine learning equivalents?

# %% [markdown]
# Ans : There are three main types of learning: classical conditioning, operant conditioning, and observational learning. Classical conditioning is a learning process that occurs when two stimuli are repeatedly paired: a response which is at first elicited by the second stimulus is eventually elicited by the first stimulus alone. Operant conditioning is conditioning in which the desired behavior or increasingly closer approximations to it are followed by a rewarding or reinforcing stimulus — compare classical conditioning. This is similar to reinforcing learning in machine learning. Observational learning is observational learning, method of learning that consists of observing and modeling another individual's behavior, attitudes, or emotional expressions. This can be thought as supervised learning in machine learning.

# %% [markdown]
# <b>Q.3 What is machine learning, and how does it work? What are the key responsibilities of machine
# learning?

# %% [markdown]
# Ans : Machine learning is the study of computer algorithms that can improve automatically through experience and by the use of data. Key responsibilities of machine learning is to understand the data, get insights into the data, try to classify the labels

# %% [markdown]
# <b>Q.4 Define the terms &quot;penalty&quot; and &quot;reward&quot; in the context of reinforcement learning.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# The above image shows the robot, diamond, and fire. The goal of the robot is to get the reward that is the diamond and avoid the hurdles that are fired. The robot learns by trying all the possible paths and then choosing the path which gives him the reward with the least hurdles. Each right step will give the robot a reward and each wrong step will subtract the reward, i.e. it will penalize the model for each wrong step of the robot. The total reward will be calculated when it reaches the final reward that is the diamond. Reinforcement learning do not have correct labels to train itself, it has to try all the ways and find out the best possible solution

# %% [markdown]
# <b>Q.5 Explain the term &quot;learning as a search&quot;?

# %% [markdown]
# Ans : Learning can be viewed as a search through the space of all sentences in a language for a sentence that best describes the data. When the search space is small, it is possible to use “brute force” search methods. If the search space is very large, additional knowledge is required to reduce the search.

# %% [markdown]
# <b>Q.6 What are the various goals of machine learning? What is the relationship between these and
# human learning?

# %% [markdown]
# Ans : The goal of machine learning is to get good insights into the data. Learn the pattern, understand and learn both human learning and other forms of learning

# %% [markdown]
# <b>Q.7 Illustrate the various elements of machine learning using a real-life illustration.

# %% [markdown]
# Ans: The various elements of machine learning are Data,Task, Model, Loss function, Learning algorithm, Evaluation

# %% [markdown]
# <b>Q.8 What is the concept of generalization? What function does it play in the machine learning
# process?

# %% [markdown]
# Ans : Generalization error can be given as Bias^2 + varience. Bias is a term in which we make assumptions like the disribution is gaussian, data is linearly seperable etc, is can also be thought as underfitting, variance means that we are we very strict with the pattern, that is the model is overfitting. We have to find the optimum bias and varience so that out model is niether overfitting nor underfitting.

# %% [markdown]
# <b>Q.10 What is classification, exactly? What are the main distinctions between classification and regression?

# %% [markdown]
# Ans : In machine learning, classification refers to a predictive modeling problem where a class label is predicted for a given example of input data. Examples of classification problems include: Given an example, classify if it is spam or not. Classfication can be binary class or even multiclass, some algorithm used to solve classification problems are Logistic regression, naive bayes, SVM etc. Base difference between classification and regression is that, classification is used to predict distinct value, while regression is used to predict continous value. In solving classification we generally take majority vote, and in regression we take generally average to predict the label

# %% [markdown]
# <b>Q.11 What is regression, and how does it work?

# %% [markdown]
# In regression, we normally have one dependent variable and one or more independent variables. Here we try to regress the value of dependent variable Y with the help of the independent variables. In other words, we are trying to understand, how does the value of Y change w.r.t change in X. The linear equation of 2D is y = mx + c. We compute the distance of each point from this is line and calculate sum (y_actual - y_pred)^2 we try to minimize this value. Example would be to solve and predict the GRE score of student, or predict the sales in dollars etc

# %% [markdown]
# <b>Q.12 Describe the clustering mechanism in detail.

# %% [markdown]
# Ans : Clustering techniques are usually used to cluster similar data points. We try to minimize the intracluster distance i.e. the distance between points within a cluster, and maximize the intercluster distance, i.e. the distance between the clusters. We have various algorithms like kmeans++ and DBSCAN. Kmeans works by minimizing intra cluster distance and maximizing intercluster distance. We can find the best value of cluster by making a cluster vs WCSS graph, using elbow method we can get the best value of cluster, that can minimize intra cluster distance and maximize intercluster distance

# %% [markdown]
# <b>Q.13 Make brief observations on two of the following topics:
#     <br>
#     1. Studying under supervision <br>
#     2. Studying without supervision

# %% [markdown]
# Ans :- Studying under supervision is like studying with a teacher, where the teacher will correct you based on the answers you give, and then the learning will happen. Similary a machine learning algorithm can be made to learn using target label, where the algorithm will predict and check if the prediction is correct, based on the loss generated, the machine learning algoritm will update its parameters and decrease the loss. Studying without supervision do not have the target label, so the model has to understand or discover the pattern in the data by itself, and minimize the loss to get the best results
